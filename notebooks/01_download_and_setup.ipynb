# %% [markdown]
# # Notebook 01: Download and Setup
#
# This notebook downloads all required data and sets up the project environment.

# %%
# Import all required libraries
import os
import numpy as np
import pandas as pd
from pathlib import Path
from nilearn import datasets
import shutil
from tqdm import tqdm

print("✓ All required libraries imported successfully")
# Out:
# ✓ All required libraries imported successfully

# %%
# Set random seed for reproducibility
np.random.seed(42)

print("✓ Random seed set to 42 for reproducibility")
# Out:
# ✓ Random seed set to 42 for reproducibility

# %%
# Define base project directory (parent of notebooks directory)
notebook_dir = Path.cwd()
project_dir = notebook_dir.parent

# Define data directories
data_dir = project_dir / 'data'
figures_dir = project_dir / 'figures'
results_dir = project_dir / 'results'

# Create directories if they don't exist
data_dir.mkdir(parents=True, exist_ok=True)
figures_dir.mkdir(parents=True, exist_ok=True)
results_dir.mkdir(parents=True, exist_ok=True)

print(f"✓ Project directory: {project_dir}")
print(f"✓ Data directory: {data_dir}")
print(f"✓ Figures directory: {figures_dir}")
print(f"✓ Results directory: {results_dir}")
# Out:
# ✓ Project directory: c:\Users\mmsid\Documents\github\My Project\human-brain-connectome
# ✓ Data directory: c:\Users\mmsid\Documents\github\My Project\human-brain-connectome\data
# ✓ Figures directory: c:\Users\mmsid\Documents\github\My Project\human-brain-connectome\figures
# ✓ Results directory: c:\Users\mmsid\Documents\github\My Project\human-brain-connectome\results

# %%
# Download Destrieux 2009 atlas via nilearn
print("Downloading Destrieux 2009 atlas...")
try:
    atlas = datasets.fetch_atlas_destrieux_2009(lateralized=True)
    atlas_path = atlas['maps']
    print(f"✓ Destrieux 2009 atlas downloaded successfully")
    print(f"  Atlas path: {atlas_path}")
    print(f"  Number of regions: 163 (bilaterally organized)")
except Exception as e:
    print(f"✗ Error downloading atlas: {e}")
# Out:
# Downloading Destrieux 2009 atlas...
#
# Added README.md to C:\Users\mmsid/nilearn_data
#
#
# Dataset created in C:\Users\mmsid/nilearn_data\destrieux_2009
#
# Downloading data from https://www.nitrc.org/frs/download.php/11942/destrieux2009.tgz ...
# ✓ Destrieux 2009 atlas downloaded successfully
#   Atlas path: C:\Users\mmsid/nilearn_data\destrieux_2009\destrieux2009_rois_lateralized.nii.gz
#   Number of regions: 163 (bilaterally organized)
#  ...done. (1 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\destrieux_2009\2a2e5a5707983d509d9319c692c867ab\destrieux2009.tgz..... done.

# %%
# Download ADHD resting-state fMRI dataset (20 subjects)
print("\nDownloading ADHD200 resting-state fMRI dataset...")
try:
    adhd_dataset = datasets.fetch_adhd(n_subjects=20)
    func_files = adhd_dataset.func
    confound_files = adhd_dataset.confounds
    
    print(f"✓ ADHD200 dataset downloaded successfully")
    print(f"  Number of subjects: {len(func_files)}")
    print(f"  Resting-state fMRI files: {len(func_files)}")
    print(f"  Confound files: {len(confound_files)}")
except Exception as e:
    print(f"✗ Error downloading ADHD dataset: {e}")
# Out:
# Downloading ADHD200 resting-state fMRI dataset...
#
# Dataset created in C:\Users\mmsid/nilearn_data\adhd
#
# Downloading data from https://www.nitrc.org/frs/download.php/7781/adhd40_metadata.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\fbef5baff0b388a8c913a08e1d84e059\adhd40_metadata.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7782/adhd40_0010042.tgz ...
# Downloaded 19070976 of 44414948 bytes (42.9%,    1.3s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0010042.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7783/adhd40_0010064.tgz ...
# Downloaded 29769728 of 45583539 bytes (65.3%,    0.5s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0010064.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7784/adhd40_0010128.tgz ...
# Downloaded 29114368 of 45461055 bytes (64.0%,    0.6s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0010128.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7785/adhd40_0021019.tgz ...
# Downloaded 32317440 of 46216320 bytes (69.9%,    0.4s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0021019.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7786/adhd40_0023008.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0023008.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7787/adhd40_0023012.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0023012.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7788/adhd40_0027011.tgz ...
# Downloaded 55566336 of 72402326 bytes (76.7%,    0.6s remaining) ...done. (3 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0027011.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7789/adhd40_0027018.tgz ...
# Downloaded 58834944 of 76184603 bytes (77.2%,    0.6s remaining) ...done. (3 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0027018.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7790/adhd40_0027034.tgz ...
# Downloaded 63660032 of 70074120 bytes (90.8%,    0.2s remaining) ...done. (3 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0027034.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7791/adhd40_0027037.tgz ...
# Downloaded 51650560 of 69291635 bytes (74.5%,    0.7s remaining) ...done. (3 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_0027037.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7792/adhd40_1019436.tgz ...
# Downloaded 24076288 of 41803342 bytes (57.6%,    0.7s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_1019436.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7793/adhd40_1206380.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_1206380.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7794/adhd40_1418396.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_1418396.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7795/adhd40_1517058.tgz ...
# Downloaded 61693952 of 62682233 bytes (98.4%,    0.0s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_1517058.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7796/adhd40_1552181.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_1552181.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7797/adhd40_1562298.tgz ...
# Downloaded 53403648 of 60663491 bytes (88.0%,    0.3s remaining) ...done. (3 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_1562298.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7798/adhd40_1679142.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_1679142.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7799/adhd40_2014113.tgz ...
# Downloaded 21749760 of 33119052 bytes (65.7%,    0.5s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_2014113.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7800/adhd40_2497695.tgz ...
# Downloaded 23044096 of 45455025 bytes (50.7%,    1.0s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_2497695.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7801/adhd40_2950754.tgz ...
# Downloaded 53968896 of 57992968 bytes (93.1%,    0.1s remaining) ...done. (2 seconds, 0 min)
# Extracting data from C:\Users\mmsid/nilearn_data\adhd\51410fe6114f7970e5387710230b41f5\adhd40_2950754.tgz...
# ✓ ADHD200 dataset downloaded successfully
#   Number of subjects: 20
#   Resting-state fMRI files: 20
#   Confound files: 20
# .. done.

# %%
# Save dataset paths to a config dictionary
config = {
    'atlas_path': str(atlas_path),
    'n_subjects': len(func_files),
    'func_files': [str(f) for f in func_files],
    'confound_files': [str(f) for f in confound_files],
    'tr': 2.5,  # Repetition time in seconds
    'n_regions': 163,  # Destrieux atlas
    'data_dir': str(data_dir),
    'figures_dir': str(figures_dir),
    'results_dir': str(results_dir),
    'project_dir': str(project_dir)
}

print("✓ Configuration dictionary created")
print(f"  Project contains {config['n_subjects']} subjects")
print(f"  Using {config['n_regions']} brain regions from Destrieux atlas")
print(f"  TR = {config['tr']} seconds")
# Out:
# ✓ Configuration dictionary created
#   Project contains 20 subjects
#   Using 163 brain regions from Destrieux atlas
#   TR = 2.5 seconds

# %%
# Save config dictionary as JSON for use in other notebooks
import json

config_path = data_dir / 'config.json'
with open(config_path, 'w') as f:
    json.dump(config, f, indent=4)

print(f"✓ Configuration saved to {config_path}")
# Out:
# ✓ Configuration saved to c:\Users\mmsid\Documents\github\My Project\human-brain-connectome\data\config.json

# %%
# Print summary of what was downloaded
print("\n" + "="*60)
print("PROJECT SETUP SUMMARY")
print("="*60)
print(f"\nDataset Information:")
print(f"  Dataset: ADHD200 Resting-State fMRI")
print(f"  Number of subjects: {config['n_subjects']}")
print(f"  Brain atlas: Destrieux 2009 (lateralized)")
print(f"  Number of regions: {config['n_regions']}")
print(f"  Repetition time (TR): {config['tr']} seconds")
print(f"\nProject Directories:")
print(f"  Project root: {config['project_dir']}")
print(f"  Data: {config['data_dir']}")
print(f"  Figures: {config['figures_dir']}")
print(f"  Results: {config['results_dir']}")
print(f"\nNext Step: Run Notebook 02 (Extract Brain Signals)")
print("="*60)
# Out:
# ============================================================
# PROJECT SETUP SUMMARY
# ============================================================
#
# Dataset Information:
#   Dataset: ADHD200 Resting-State fMRI
#   Number of subjects: 20
#   Brain atlas: Destrieux 2009 (lateralized)
#   Number of regions: 163
#   Repetition time (TR): 2.5 seconds
#
# Project Directories:
#   Project root: c:\Users\mmsid\Documents\github\My Project\human-brain-connectome
#   Data: c:\Users\mmsid\Documents\github\My Project\human-brain-connectome\data
#   Figures: c:\Users\mmsid\Documents\github\My Project\human-brain-connectome\figures
#   Results: c:\Users\mmsid\Documents\github\My Project\human-brain-connectome\results
#
# Next Step: Run Notebook 02 (Extract Brain Signals)
# ============================================================
